# %% [markdown]
# Code from https://lightning.ai/docs/torchmetrics/stable/gallery/audio/pesq.html

# %%
# %pip install torchmetrics pesq

import matplotlib.pyplot as plt
import numpy as np 
import torch
import torchaudio 

from torchmetrics.audio.pesq import PerceptualEvaluationSpeechQuality
# Out:
# Requirement already satisfied: torchmetrics in c:\users\e7440\documents\uni2025\investigation\project-25p85\.venv\lib\site-packages (1.7.4)
# Collecting pesq
#   Downloading pesq-0.0.4.tar.gz (38 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy>1.20.0 in c:\users\e7440\documents\uni2025\investigation\project-25p85\.venv\lib\site-packages (from torchmetrics) (2.3.1)
# Requirement already satisfied: packaging>17.1 in c:\users\e7440\documents\uni2025\investigation\project-25p85\.venv\lib\site-packages (from torchmetrics) (25.0)
# Requirement already satisfied: torch>=2.0.0 in c:\users\e7440\documents\uni2025\investigation\project-25p85\.venv\lib\site-packages (from torchmetrics) (2.7.1)
# Requirement already satisfied: lightning-utilities>=0.8.0 in c:\users\e7440\documents\uni2025\investigation\project-25p85\.venv\lib\site-packages (from torchmetrics) (0.14.3)
# Requirement already satisfied: setuptools in c:\users\e7440\documents\uni2025\investigation\project-25p85\.venv\lib\site-packages (from lightning-utilities>=0.8.0->torchmetrics) (65.5.0)
# Requirement already satisfied: typing_extensions in c:\users\e7440\documents\uni2025\investigation\project-25p85\.venv\lib\site-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.14.0)
# Requirement already satisfied: filelock in c:\users\e7440\documents\uni2025\investigation\project-25p85\.venv\lib\site-packages (from torch>=2.0.0->torchmetrics) (3.18.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\e7440\documents\uni2025\investigation\project-25p85\.venv\lib\site-packages (from torch>=2.0.0->torchmetrics) (1.14.0)
# Requirement already satisfied: networkx in c:\users\e7440\documents\uni2025\investigation\project-25p85\.venv\lib\site-packages (from torch>=2.0.0->torchmetrics) (3.5)
# Requirement already satisfied: jinja2 in c:\users\e7440\documents\uni2025\investigation\project-25p85\.venv\lib\site-packages (from torch>=2.0.0->torchmetrics) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\e7440\documents\uni2025\investigation\project-25p85\.venv\lib\site-packages (from torch>=2.0.0->torchmetrics) (2025.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\e7440\documents\uni2025\investigation\project-25p85\.venv\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\e7440\documents\uni2025\investigation\project-25p85\.venv\lib\site-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.2)
# Building wheels for collected packages: pesq
#   Building wheel for pesq (pyproject.toml): started
#   Building wheel for pesq (pyproject.toml): finished with status 'done'
#   Created wheel for pesq: filename=pesq-0.0.4-cp311-cp311-win_amd64.whl size=116594 sha256=0bb46f2dff6633afd370f2b68ccdd1fa97575b5499cb6bc2d35ea55ba9afbe90
#   Stored in directory: c:\users\e7440\appdata\local\pip\cache\wheels\ae\f1\23\2698d0bf31eec2b2aa50623b5d93b6206c49c7155d0e31345d
# Successfully built pesq
# Installing collected packages: pesq
# Successfully installed pesq-0.0.4
# Note: you may need to restart the kernel to use updated packages.

# %%
def generate_sine_wave(frequency, duration, sample_rate, amplitude: float = 0.5): 
    """ Generate a clean sine wave at a given frequency. """
    t = torch.linspace(0,duration,int(sample_rate*duration))
    return amplitude*torch.sin(2*np.pi*frequency*t)
